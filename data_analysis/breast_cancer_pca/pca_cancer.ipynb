# %% [markdown]
# # defining the dataset

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer

# %%
breast = load_breast_cancer()
breast.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
target_names = breast.target_names
target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
data = breast.data
data.shape
# Out:
# (569, 30)

# %%
target = breast.target

target.shape
# Out:
# (569,)

# %%
target = target.reshape(569,1)

# %%
# combine the data and target values
df = np.concatenate([data,target],axis=1)

df = pd.DataFrame(df)
df.head()
# Out:
#       0      1       2       3        4        5       6        7       8   \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         9   ...     21      22      23      24      25      26      27  \
# 0  0.07871  ...  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        28       29   30
# 0  0.4601  0.11890  0.0
# 1  0.2750  0.08902  0.0
# ...

# %%
# find the column names:
features = breast.feature_names
features
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
# add the target column name
features = np.append(features,'target')

# %%
df.columns = features
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df['target'].replace({0.0:'Benign',1:'Malignant'},inplace=True)
df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
# ...

# %% [markdown]
# # normalization :

# %%
from sklearn.preprocessing import StandardScaler

# %%
# normalized data with mean=0 and std=1
data_norm = StandardScaler().fit_transform(data)
data_norm.shape
# Out:
# (569, 30)

# %%
np.mean(data_norm)
# Out:
# -6.118909323768877e-16

# %%
np.std(data_norm)
# Out:
# 1.0

# %% [markdown]
# # PCA :

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
pca.fit(data_norm)
data = pca.transform(data_norm)

# %%
pca_df = pd.DataFrame(data = data,columns=['PC1','PC2'])
pca_df
# Out:
#            PC1        PC2
# 0     9.192837   1.948583
# 1     2.387802  -3.768172
# 2     5.733896  -1.075174
# 3     7.122953  10.275589
# 4     3.935302  -1.948072
# ..         ...        ...
# 564   6.439315  -3.576817
# 565   3.793382  -3.584048
# 566   1.256179  -1.902297
# 567  10.374794   1.672010
# 568  -5.475243  -0.670637
#
# [569 rows x 2 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.44272026, 0.18971182])

# %%
plt.figure()
plt.figure(figsize=(10,10))

plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)

labels=['Benign','Malignant']
colors = ['r','b']

for label,color in zip(labels,colors):
    index = df[df['target'] == label].index
    plt.scatter(pca_df.iloc[index,0],pca_df.iloc[index,1],color=color)

plt.legend(labels)
    
plt.show()

# %%
import matplotlib.pyplot as plt

pd.plotting.scatter_matrix(pca_df)
plt.show()

# %%
pca = PCA(n_components=4)
pca.fit(data_norm)
data = pca.transform(data_norm)

pca_df = pd.DataFrame(data = data,columns=['PC1','PC2','PC3','PC4'])

pca.explained_variance_ratio_
# Out:
# array([0.44272026, 0.18971182, 0.09393163, 0.06602135])

# %%
comps = pca.components_

# %%
ax = plt.gca()
img = ax.imshow(comps, cmap='seismic', vmin=-1, vmax=1)
ax.set_title('Component Matrix')
plt.colorbar(img, label="weight")
ax.set_yticks([0,1,2,3])
t = ax.set_yticklabels(["PC{}".format(i+1) for i in range(4)])
ax.set_xticks(list(range(0, len(features)-1)))
t = ax.set_xticklabels(features, rotation=90)

plt.show()

# %%
# of the above matrix, only the first 2 rows have significance, and if the weight of one of the features is less in 
# PC1 then that feature contributes very little information. And if a feature has a high weightage but is part of PC3 
# then that feature is still not significant because it is part of PC3 and PC3 has very little variation (info)

# %%
plt.rcParams["figure.figsize"] = (20,15)
pd.plotting.scatter_matrix(pca_df)
plt.show()
