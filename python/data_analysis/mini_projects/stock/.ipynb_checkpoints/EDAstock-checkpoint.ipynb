# %%
#Import libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn; seaborn.set()
# %matplotlib inline
import os
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing

# %%
os.chdir('C:/Users/..../My Desktop/FT')

# %%
stock = pd.read_excel("nifty_ts.xlsx")

# %%
stock
# Out:
#              Prices   Returns
# Date
# 2003-01-01  1100.15  0.006063
# 2003-01-02  1093.05 -0.006475
# 2003-01-03  1089.60 -0.003161
# 2003-01-06  1084.35 -0.004830
# 2003-01-07  1081.80 -0.002354
# ...             ...       ...
# 2003-12-26  1837.05  0.015553
# 2003-12-29  1874.05  0.019941
# 2003-12-30  1873.25 -0.000427
# 2003-12-31  1879.75  0.003464
# 2004-01-02  1946.05  0.034663
#
# [255 rows x 2 columns]

# %%
stock.isnull().any()
# Out:
# Prices     False
# Returns    False
# dtype: bool

# %%
stock.describe()
# Out:
#             Prices     Returns
# count   255.000000  255.000000
# mean   1236.498627    0.002260
# std     257.669627    0.012465
# min     924.300000   -0.043371
# 25%    1037.175000   -0.005685
# 50%    1133.800000    0.003745
# 75%    1459.875000    0.009834
# max    1946.050000    0.036385

# %%
#plotting stock price trend
ax1 = stock['Prices'].plot(style=['-'])
plt.title("Stock Prices")

ax1.legend()
plt.plot()
# Out:
# []

# %%
#plotting return
ax2 = stock['Returns'].plot(style=['-'])
plt.title("Returns")

ax2.legend()
plt.plot()
# Out:
# []

# %%
# Plot both
plt.plot(stock['Prices'])
plt.title('Stock Price')
plt.ylabel('Price');
plt.show()

plt.plot(stock['Returns'],'r')
plt.title('Stock Return')
plt.ylabel('Return');
plt.show();

# %%
#dotted plot

stock['Prices'].plot(style='k.')
plt.show()

# %%
#dotted plot
stock['Returns'].plot(style='k.')
plt.show()

# %%
#Histogram of prices
stock['Prices'].hist()
plt.show()

# %%
#Histogram of Returns
#Histogram
stock['Returns'].hist()
plt.show()

# %%
#Kernel Density plot

stock['Prices'].plot(kind='kde')
plt.show()

stock['Returns'].plot(kind='kde')
plt.show()

# %%
#plotting moving average (rolling mean of Prices)
price_mean = stock['Prices'].rolling(20,win_type=None).mean()
price_mean.plot(style=['-', '--', ':'])

# %%
#plotting moving average (rolling mean of Returns)
price_mean = stock['Returns'].rolling(30,win_type=None).mean()
price_mean.plot(style=['-', '--', ':'])

# %%
#Exponetial smoothing

from statsmodels.tsa.holtwinters import SimpleExpSmoothing

model = SimpleExpSmoothing(stock['Prices']).fit(smoothing_level=.1,optimized=True)

stock['Prices'].plot(marker='o', color='red')
model.fittedvalues.plot(marker='o', color='blue')
# Out:
# C:\Users\PaniB\Anaconda4\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\PaniB\Anaconda4\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
#Lag plot - it is used to check if the series is random or not
from pandas.plotting import lag_plot
lag_plot(stock['Prices'])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#exhibits a linear pattern.
#This shows that the data are strongly non-random and further suggests that an autoregressive model might be appropriate.

# %%
#Autocorrelation plot

from pandas.plotting import autocorrelation_plot
autocorrelation_plot(stock['Prices'])

# %%
#Partial Autocorrelation

from pandas import Series
from statsmodels.graphics.tsaplots import plot_pacf

#pacf
plot_pacf(stock['Prices'], lags=5)
