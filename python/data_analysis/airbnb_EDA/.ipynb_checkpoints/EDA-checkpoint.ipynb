# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import swifter

# %%
df = pd.read_csv('/Users/alenjose/Desktop/data/airbnb_EDA/listings.csv')
df.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  528022  https://www.airbnb.com/rooms/528022  20221205143541   2022-12-05
# 1    2818    https://www.airbnb.com/rooms/2818  20221205143541   2022-12-05
#
#         source                                       name  \
# 0  city scrape                             Somewhere Else
# 1  city scrape  Quiet Garden View Room & Super Fast Wi-Fi
#
#                                          description  \
# 0  Highlights<br />*Located only 5 minutes from C...
# 1  Quiet Garden View Room & Super Fast Wi-Fi<br /...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Indische Buurt ("Indies Neighborhood") is a ne...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/bf6fa79c-5863...  2594559  ...
# 1  https://a0.muscache.com/pictures/10272854/8dcc...     3159  ...
#
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  6.809000e+03  6.809000e+03  6.809000e+03          6809.000000
# mean   1.543801e+17  2.022121e+13  9.757724e+07             2.801146
# std    2.861175e+17  1.793100e+00  1.315182e+08            18.066322
# min    2.818000e+03  2.022121e+13  3.159000e+03             1.000000
# 25%    1.510977e+07  2.022121e+13  9.287585e+06             1.000000
# 50%    3.373018e+07  2.022121e+13  3.321458e+07             1.000000
# 75%    5.313791e+07  2.022121e+13  1.336823e+08             2.000000
# max    7.743397e+17  2.022121e+13  4.901557e+08           799.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                6809.000000                           0.0  6809.000000
# mean                    4.819944                           NaN    52.366847
# std                    29.766061                           NaN     0.017026
# ...

# %%
# total number of columns
len(df.columns)
# Out:
# 75

# %%
# columns with null values
len(df.columns[df.isnull().any()])
# Out:
# 27

# %%
# check for duplicated rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # What is the distribution of Airbnb listings by property type?

# %%
sns_plot = sns.countplot(x='room_type', data=df)

plt.title('Number of Airbnb listings by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Number of Listings')


for p in sns_plot.patches:
        sns_plot.annotate(format(p.get_height(), '.0f'), 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha = 'center', va = 'center', 
                          xytext = (0, 10), 
                          textcoords = 'offset points')
        
ylim = sns_plot.get_ylim()
sns_plot.set_ylim(ylim[0], ylim[1] * 1.1) 
        

plt.tight_layout()
plt.show()

# %% [markdown]
# # How does the price of Airbnb listings vary by property type and location?

# %%
# use str to call str functions on a column 
df['price'].str.contains('$').sum()
# Out:
# 6809

# %%
df['price'] = df['price'].apply(lambda x:x.replace('$',''))
df['price'] = df['price'].apply(lambda x:x.replace(',',''))
df['price'] = pd.to_numeric(df['price'])

# %%
mean_prices_by_type = df.groupby('room_type')['price'].mean().reset_index()

# Plot the mean prices by room type using seaborn
sns_plot = sns.barplot(x='room_type', y='price', data=mean_prices_by_type)

# Add a title and labels to the plot
plt.title('Mean Price of Airbnb Listings by Property Type')
plt.xlabel('Room Type')
plt.ylabel('Mean Price')

# Add the values on top of the bars
if sns_plot is not None:
    for p in sns_plot.patches:
        sns_plot.annotate(format(p.get_height(), '.2f'), 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha = 'center', va = 'center', 
                          xytext = (0, 5), 
                          textcoords = 'offset points')

# %% [markdown]
# # What is the average availability of Airbnb listings by neighborhood and property type?

# %%
df['has_availability'].value_counts()
# Out:
# t    6756
# f      53
# Name: has_availability, dtype: int64

# %%
df['has_availability'] = df['has_availability'].apply(lambda x: 1 if x == 't' else 0)

# %%
merged = pd.merge(df.groupby('neighbourhood')['has_availability'].sum().reset_index(),
          df.groupby('neighbourhood')['has_availability'].count().reset_index(),
            on='neighbourhood', how='inner')
merged['percent'] = round((merged['has_availability_x'] / merged['has_availability_y']) * 100,1)
merged.sort_values('has_availability_x',ascending=False)[['neighbourhood','percent']].head(5)
# Out:
#                                      neighbourhood  percent
# 27           Amsterdam, Noord-Holland, Netherlands     99.2
# 29           Amsterdam, North Holland, Netherlands     99.8
# 21                      Amsterdam, NH, Netherlands     99.5
# 24                          Amsterdam, Netherlands    100.0
# 34  Amsterdam-Zuidoost, Noord-Holland, Netherlands    100.0

# %%
merged = pd.merge(df.groupby('room_type')['has_availability'].sum().reset_index(),
          df.groupby('room_type')['has_availability'].count().reset_index(),
            on='room_type', how='inner')
merged = merged.rename(columns={'has_availability_x': 'available', 'has_availability_y': 'total_count'})
merged['percent_available'] = round((merged['available'] / merged['total_count']) * 100, 1)
merged.sort_values('available',ascending=False)
# Out:
#          room_type  available  total_count  percent_available
# 0  Entire home/apt       4863         4910               99.0
# 2     Private room       1793         1798               99.7
# 1       Hotel room         61           62               98.4
# 3      Shared room         39           39              100.0

# %% [markdown]
# # Which amenities are most commonly offered in Airbnb listings?

# %%
import ast
df['amenities'] = df['amenities'].apply(lambda x:ast.literal_eval(x))

# %%
amenities_lst = []
_ = df['amenities'].apply(lambda x: [amenities_lst.append(i) for i in x])

# %%
amenities_set = set()
for i in amenities_lst:
    amenities_set.add(i)
amenities_dict = {key: 0 for key in amenities_set}

for key in amenities_lst:
    amenities_dict[key] = amenities_dict[key] + 1

# %%
pd.DataFrame(list(amenities_dict.items()), columns=['amenities', 'total_count'])\
    .sort_values(by='total_count',ascending=False).head(15)\
        .set_index('amenities')
# Out:
#                          total_count
# amenities
# Essentials                      6073
# Smoke alarm                     6063
# Wifi                            5962
# Kitchen                         5508
# Hot water                       5152
# Hair dryer                      5044
# Dishes and silverware           5019
# Hangers                         4919
# Long term stays allowed         4898
# Refrigerator                    4765
# Iron                            4703
# Heating                         4697
# Bed linens                      4338
# Shampoo                         4158
# Cooking basics                  4157

# %%
amenities_df = pd.DataFrame(list(amenities_dict.items()), columns=['amenities', 'count'])
top15 = amenities_df.sort_values(by='count', ascending=False).head(15)

# create figure and axis
fig, ax = plt.subplots()
sns.barplot(data=top15, x='amenities', y='count', ax=ax, linewidth=3)

for p in ax.patches:
    value = p.get_height() / df.shape[0]
    text = f'{round(value * 100,1)}'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(text, (x, y), ha='center', va='bottom')

ax.set_ylim(top=top15['count'].max() * 1.4)


# set the x-tick labels to vertical
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # How do the review scores for cleanliness, check-in, communication, and value vary by property type and host characteristics?

# %%
# Groupby and compute mean for each room type and review score category
mean_review_scores = df.groupby('room_type')[['review_scores_cleanliness', 'review_scores_checkin','review_scores_communication', 'review_scores_location', 'review_scores_value']].mean()

# Create the bar plot
ax = mean_review_scores.plot(kind='bar', figsize=(10, 6), width=0.8)

# Set the legend outside the plot
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

for i in ax.containers:
    ax.bar_label(i, labels=[f'{val:.1f}' if val > 0 else '' for val in i.datavalues], label_type='edge', fontsize=10, padding=5)

ax.set_ylim(top=ax.get_ylim()[1]*1.1)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Set the plot title and axis labels
plt.title('Average Review Scores by Room Type')
plt.xlabel('Room Type')
plt.ylabel('Average Review Score')

# Show the plot
plt.show()

# %% [markdown]
# # What is the correlation between the number of bedrooms and bathrooms and the price of Airbnb listings?

# %%
plt.xlim(df['bedrooms'].min(),12)
plt.ylim(df['price'].min(), 4000)
sns.scatterplot(x='bedrooms', y='price', data=df)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_xlim(df['price'].min(), 3000)

sns.scatterplot(x='price', y='bathrooms_text', data=df, ax=ax)

# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# Set the plot title and axis labels
plt.title('Price vs Bathrooms')
plt.xlabel('Price')
plt.ylabel('Number of Bathrooms')
plt.show()

# %% [markdown]
# # How does the Airbnb listings change over time?

# %%
df['host_since'] = pd.to_datetime(df['host_since'])

# %%
fig, ax = plt.subplots(figsize=(10, 6))

df_count = df.groupby(pd.Grouper(key='host_since', freq='M'))['id'].count()

# Reset the index and rename the columns
df_count = pd.DataFrame(df_count.reset_index(name='count'))

sns.lineplot(data=df_count, x='host_since', y='count', ax=ax)

plt.show()

# %%
df_year_count = df.groupby(pd.Grouper(key='host_since', freq='Y'))['id'].count().reset_index()
df_year_count['host_since'] = df_year_count['host_since'].dt.strftime('%Y')

fig, ax = plt.subplots(figsize=(8, 5))

sns.barplot(data=df_year_count, x='host_since', y='id', ax=ax)

plt.xlabel('Year')
plt.ylabel('New Hosts')
plt.title('New Hosts Over the years')

plt.tight_layout()
plt.show()

# %% [markdown]
# **The data shows the number of new hosts who joined Airbnb each year from 2008 to 2022.
# The highest number of new hosts was recorded in 2013, with 1052 new hosts joining the platform.
# The number of new hosts has since decreased, with 220 new hosts joining in 2021 and 242 in 2022.
# The period between 2014 and 2018 saw relatively stable numbers of new hosts joining each year,
# while there was a sharp decline in 2019 before a slight increase in 2020. Overall, the data suggests
# that Airbnb's growth in terms of new hosts joining the platform has slowed in recent years.**

# %% [markdown]
# # Which neighborhoods have the highest and lowest numbers of Airbnb listings?

# %%
# neighbourhood with highest listings
df.groupby('neighbourhood')['id'].count().sort_values(ascending=False).head(1)
# Out:
# neighbourhood
# Amsterdam, Noord-Holland, Netherlands    3579
# Name: id, dtype: int64

# %%
# neighbourhood's with only 1 listing
print("There are",len(df.groupby('neighbourhood')['id'].count().sort_values(ascending=False).values == 1),
      "neighbourhood's with only 1 listing")
# Out:
# There are 48 neighbourhood's with only 1 listing

# %% [markdown]
# # What is the average number of reviews per month for Airbnb listings vary by neighbourhood and property type?

# %%
neigh_rev = df.groupby('neighbourhood')['reviews_per_month'].mean()\
                             .sort_values(ascending=False).head(10).reset_index()
neigh_rev['neighbourhood'] = neigh_rev['neighbourhood'].str.replace(', Netherlands','')

sns.barplot(x='reviews_per_month',y='neighbourhood',data=neigh_rev)

plt.title('AVG Number of Reviews Per Neighbourhood')
plt.show()

# %% [markdown]
# # What are the most common reasons cited by guests for giving low review scores, and are these reasons more prevalent in certain neighborhoods or property types?

# %%
df1 = pd.read_csv('/Users/alenjose/Desktop/data/airbnb_EDA/reviews.csv')

# %%
import nltk
nltk.download('stopwords')
import string

from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
punctuation = string.punctuation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alenjose/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def filter_func(x):
    try:
        tokens = nltk.word_tokenize(x)
        filtered_tokens = [word for word in tokens if word.lower() not in stop_words]    
    except:
        filtered_tokens = 'none'
    return filtered_tokens

df1['filtered'] = df1['comments'].swifter.apply(lambda x:filter_func(x))
# Out:
# Pandas Apply:   0%|          | 0/326833 [00:00<?, ?it/s]

# %%
def remove_punc(x):
    try:
        lst = [word for word in x if word not in punctuation]
    except:
        lst = 'none'
    return lst

# %%
from textblob import TextBlob

def get_sentiment(x):
    blob = TextBlob(" ".join(remove_punc(x)))
    sentiment = blob.sentiment
    return sentiment.polarity,sentiment.subjectivity

df1['filtered'] = df1['filtered'].swifter\
     .apply(lambda x:get_sentiment(x))
# Out:
# Pandas Apply:   0%|          | 0/326833 [00:00<?, ?it/s]

# %%
df1['polarity'] = df1['filtered'].apply(lambda x:x[0])
df1['subjectivity'] = df1['filtered'].apply(lambda x:x[1])
df1.drop('filtered',axis=1,inplace=True)
df1 = df1.groupby('listing_id')[['polarity','subjectivity']].mean()

# %%
merged = pd.merge(df[['id','review_scores_rating']],
         df1,
         left_on='id',
         right_on='listing_id',
         how='inner')
merged['polarity'] = merged['polarity'].apply(lambda x:x*100)
merged
# Out:
#           id  review_scores_rating   polarity  subjectivity
# 0     528022                  4.85  30.773719      0.511721
# 1       2818                  4.89  34.202471      0.544361
# 2      20168                  4.44  31.524569      0.541030
# 3      27886                  4.94  39.219206      0.601008
# 4      28871                  4.88  36.787176      0.529906
# ...      ...                   ...        ...           ...
# 6156  794322                  4.76  37.460669      0.597704
# 6157  800723                  4.83  36.563299      0.586347
# 6158  801544                  4.57  35.735299      0.566665
# 6159  802052                  4.93  33.722920      0.521740
# 6160  805330                  4.94  43.702944      0.600652
#
# [6161 rows x 4 columns]

# %%
sns.scatterplot(x='polarity',y='review_scores_rating',data=merged)
plt.show()
