# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
transaction = pd.read_csv('/Users/alenjose/Desktop/data/kpmg_internship/edited/transaction.csv')
newCustomer = pd.read_csv('/Users/alenjose/Desktop/data/kpmg_internship/edited/newCustomer.csv')
demographic = pd.read_csv('/Users/alenjose/Desktop/data/kpmg_internship/edited/demographic.csv')
address = pd.read_csv('/Users/alenjose/Desktop/data/kpmg_internship/edited/Address.csv')

# %%
transaction
# Out:
#        transaction_id  product_id  customer_id     transaction_date  \
# 0                   1           2         2950  2017-02-25 00:00:00
# 1                   2           3         3120  2017-05-21 00:00:00
# 2                   3          37          402  2017-10-16 00:00:00
# 3                   4          88         3135  2017-08-31 00:00:00
# 4                   5          78          787  2017-10-01 00:00:00
# ...               ...         ...          ...                  ...
# 19995           19996          51         1018  2017-06-24 00:00:00
# 19996           19997          41          127  2017-11-09 00:00:00
# 19997           19998          87         2284  2017-04-14 00:00:00
# 19998           19999           6         2764  2017-07-03 00:00:00
# 19999           20000          11         1144  2017-09-22 00:00:00
#
#       online_order order_status           brand product_line product_class  \
# ...

# %%
demographic.head(2)
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  1953-10-12     Executive Secretary
# 1                                   81  1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator  \
# 0                Health  Mass Customer                  N
# 1    Financial Services  Mass Customer                  N
#
#                         default owns_car  tenure   Age
# 0                            "'      Yes    11.0  69.0
# 1  <script>alert('hi')</script>      Yes    16.0  42.0

# %%
demographic.default.str.contains(',').sum()
# Out:
# 185

# %%
demographic.drop('default',axis=1).to_csv('/Users/alenjose/Desktop/data/kpmg_internship/edited/demographic_without_default.csv')

# %%
len(demographic)
# Out:
# 4000

# %%
len(address)
# Out:
# 3999

# %%
len(transaction)
# Out:
# 20000

# %%
address
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
newCustomer
# Out:
#      customer_id first_name  last_name  gender  \
# 0              1    Chickie    Brister    Male
# 1              2      Morly     Genery    Male
# 2              3    Ardelis  Forrester  Female
# 3              4     Lucine      Stutt  Female
# 4              5    Melinda     Hadlee  Female
# ..           ...        ...        ...     ...
# 995          996  Ferdinand  Romanetti    Male
# 996          997       Burk    Wortley    Male
# 997          998   Melloney      Temby  Female
# 998          999     Dickie    Cubbini    Male
# 999         1000      Sylas    Duffill    Male
#
#      past_3_years_bike_related_purchases         DOB  \
# 0                                     86  1957-07-12
# 1                                     69  1970-03-22
# 2                                     10  1974-08-28
# 3                                     64  1979-01-28
# 4                                     34  1965-09-21
# ..                                   ...         ...
# ...
