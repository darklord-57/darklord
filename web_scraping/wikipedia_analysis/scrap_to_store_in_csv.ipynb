# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_manufacturing_companies_by_revenue'
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest manufacturing companies by revenue - Wikipedia</title>
# ...

# %%
table = soup.find('table',class_='wikitable sortable plainrowheads')

# %%
table = table.tbody
# Out:
# <tbody><tr>
# <th scope="col">No.
# </th>
# <th scope="col">Company
# </th>
# <th scope="col">Industry
# </th>
# <th scope="col">Revenue (by US$ million)
# </th>
# <th scope="col">Headquarters
# </th></tr>
# <tr>
# <td>1</td>
# <td><a href="/wiki/Volkswagen_Group" title="Volkswagen Group">Volkswagen Group</a></td>
# <td>Automotive</td>
# <td>288,888</td>
# <td><span class="datasortkey" data-sort-value="Germany"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/23px-Flag_of_Germany.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/35px-Flag_of_Germany.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/46px-Flag_of_Germany.svg.png 2x" width="23"/> </span><a href="/wiki/Germany" title="Germany">Germany</a></span>
# </td></tr>
# <tr>
# <td>2</td>
# ...

# %%
rows = table.find_all('tr')

rows[0]
# Out:
# <tr>
# <th scope="col">No.
# </th>
# <th scope="col">Company
# </th>
# <th scope="col">Industry
# </th>
# <th scope="col">Revenue (by US$ million)
# </th>
# <th scope="col">Headquarters
# </th></tr>

# %%
cols = [i.text for i in rows[0].find_all('th')]
cols = [i.strip() for i in cols]
cols
# Out:
# ['No.', 'Company', 'Industry', 'Revenue (by US$ million)', 'Headquarters']

# %%
df = pd.DataFrame(columns=cols)

# %%
rows[1].find_all('td')
# Out:
# [<td>1</td>,
#  <td><a href="/wiki/Volkswagen_Group" title="Volkswagen Group">Volkswagen Group</a></td>,
#  <td>Automotive</td>,
#  <td>288,888</td>,
#  <td><span class="datasortkey" data-sort-value="Germany"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/23px-Flag_of_Germany.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/35px-Flag_of_Germany.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/46px-Flag_of_Germany.svg.png 2x" width="23"/> </span><a href="/wiki/Germany" title="Germany">Germany</a></span>
#  </td>]

# %%
master_list = []
for i in range(1,len(rows)):
    tds = rows[i].find_all('td')
    
    vals = [td.text.strip() for td in tds]
    vals[4] = vals[4].replace('\xa0','')
    
    d = {}
    d['No'] = vals[0]
    d['Company'] = vals[1]
    d['Industry'] = vals[2]
    d['Revenue (by US$ million)'] = vals[3]
    d['Headquarters'] = vals[4]
    
    master_list.append(d)

master_list
# Out:
# [{'No': '1',
#   'Company': 'Volkswagen Group',
#   'Industry': 'Automotive',
#   'Revenue (by US$ million)': '288,888',
#   'Headquarters': 'Germany'},
#  {'No': '2',
#   'Company': 'Toyota Group',
#   'Industry': 'Engineering, various',
#   'Revenue (by US$ million)': '265,172',
#   'Headquarters': 'Japan'},
#  {'No': '3',
#   'Company': 'Apple',
#   'Industry': 'Electronics',
#   'Revenue (by US$ million)': '229,234',
#   'Headquarters': 'United States'},
#  {'No': '4',
#   'Company': 'Samsung Electronics',
#   'Industry': 'Electronics, various',
#   'Revenue (by US$ million)': '211,940',
#   'Headquarters': 'South Korea'},
#  {'No': '5',
#   'Company': 'Daimler',
#   'Industry': 'Automotive',
#   'Revenue (by US$ million)': '185,235',
#   'Headquarters': 'Germany'},
#  {'No': '6',
#   'Company': 'General Motors',
#   'Industry': 'Automotive',
#   'Revenue (by US$ million)': '157,311',
#   'Headquarters': 'United States'},
#  {'No': '7',
#   'Company': 'Ford',
# ...

# %%
df = pd.DataFrame(master_list)
df
# Out:
#      No                      Company              Industry  \
# 0     1             Volkswagen Group            Automotive
# 1     2                 Toyota Group  Engineering, various
# 2     3                        Apple           Electronics
# 3     4          Samsung Electronics  Electronics, various
# 4     5                      Daimler            Automotive
# ..  ...                          ...                   ...
# 95   96              GlaxoSmithKline       Pharmaceuticals
# 96   97                  Tyson Foods      Food & Beverages
# 97   98           Oracle Corporation           Electronics
# 98   99  Mitsubishi Heavy Industries  Engineering, various
# 99  100                      Fujitsu           Electronics
#
#    Revenue (by US$ million)                  Headquarters
# 0                   288,888                       Germany
# 1                   265,172                         Japan
# 2                   229,234                 United States
# ...

# %%
df.to_csv('list_of_companies.csv',index=0)
